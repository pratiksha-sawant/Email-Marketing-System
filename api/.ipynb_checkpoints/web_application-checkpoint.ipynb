# %%
from flask import Flask, render_template, redirect, url_for, request
# from flask_mail import Mail, Message
import urllib
import json
import requests as rq
import os
import pandas as pd
import numpy as np
import warnings
import json
from google.cloud import bigquery
from google.oauth2 import service_account
import requests

warnings.filterwarnings('ignore')

# %%
def establishConnection():
    credentials = service_account.Credentials.from_service_account_file(os.getcwd()+'/final-project-team2-3547e307824d.json')
    project_id = 'final-project-team2'
    client = bigquery.Client(credentials= credentials,project=project_id)
    return client

def getData():
    client = establishConnection()
    query = ("SELECT * FROM movielens.customers")
    query_job = client.query(
        query,# Location must match that of the dataset(s) referenced in the query.
        location="US",)  # API request - starts the query
    customer = query_job.to_dataframe()
#     customer.head()
    query = ("SELECT * FROM movielens.movies")
    query_job = client.query(
        query,# Location must match that of the dataset(s) referenced in the query.
        location="US",)  # API request - starts the query
    movies = query_job.to_dataframe()
    return customer,movies
#     movies.head()

def getCustomerInfo():
    firstnames = []
    lastnames = []
    emails = []
    mydictionary = dict()
    customer,movies = getData()
    for index, row in customer.iterrows():
        userId = row['user_id']
        firstnames.append({userId:row['first_name']})
        lastnames.append({userId:row['last_name']})
        emails.append({userId:row['email_id']})
        
    tmp = customer.set_index('user_id').T.to_dict('list')
    for key in sorted(tmp.keys()):
        mydictionary.update({key:tmp[key]})
        
    return firstnames,lastnames,emails, mydictionary

def getMovies():
    customer,movies = getData()
    moviesList = []
    for index,row in movies.iterrows():
        movieId = row['movie_id']
        moviesList.append({movieId:row['movie_title']})
    return moviesList

    
def recommendMovie(userId):
    data = {
        "Inputs":{
            "input1":
                {
                    "user_id": ["userId"],
                    "Values" : [[userId]]
                },
        },
        "GlobalParameters":{

        }
    }


    body = str.encode(json.dumps(data))
    url = 'https://ussouthcentral.services.azureml.net/workspaces/b5735f278ad44ea1b4f08ede6d289e5f/services/a1bf6e157b234b3bb5512a034b671763/execute?api-version=2.0&details=true'
    api_key = 'API_KEY ' # Replace this with the API key for the web service
    headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}
    
    req = urllib.request.Request(url, body, headers)
#     print(req)
    response = urllib.request.urlopen(req)
    result = response.read().decode('utf-8')
#     print (result)
    d = json.loads(result)
#     print(d)
#     print (d['Results']['output1']['value']['Values'])
    dlist = d['Results']['output1']['value']['Values']
    finalList = []
    for i in dlist:
        for j in range(len(i)):
            if j == 0:
                continue
            else:
                finalList.append(int(i[j]))
    return finalList

def insertData(userNum,recom):
    user = userNum
    recommendations = recom
    client = establishConnection()
    dataset_id = 'movielens'  # rep  lace with your dataset ID
    # For this sample, the table must already exist and have a defined schema
    table_id = 'recommended_movie'  # replace with your table ID
    table_ref = client.dataset(dataset_id).table(table_id)
    table = client.get_table(table_ref)  # API request

    rows_to_insert = [(user,recommendations[0],recommendations[1],recommendations[2],recommendations[3],recommendations[4])]

    errors = client.insert_rows(table, rows_to_insert)  # API request

    assert errors == []

# %% [markdown]
# ### Web Application Code

# %%
app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/about')
def about():
    return render_template('about.html')

@app.route('/marketing', methods=['POST','GET'])
def marketing():
    if request.method == 'GET':
        method = 'GET'
        frstnames,lastnames,emails,mydict = getCustomerInfo()
#         userNum = request.form['userids']
        return render_template('marketing.html',methods=method, mydict=mydict)

@app.route('/result', methods=['POST','GET'])
def marketingResult():
    if request.method == 'POST':
        method = 'POST'
        frstnames,lastnames,emails,mydict = getCustomerInfo()
        userNum= int(request.form['userids'])
        return render_template('result.html',methods=method, userNum=userNum,frstnames=frstnames,lastnames=lastnames,
                               emails=emails,mydict=mydict)

@app.route('/recommendations', methods=['POST','GET'])
def marketingRecommendations():
    if request.method == 'POST':
        method = 'POST'
        frstnames,lastnames,emails,mydict = getCustomerInfo()
        userNum= int(request.form['userid'])
        firstname= request.form['firstname']
        lastname= request.form['lastname']
        fullname = firstname + " " + lastname
        email= request.form['email']
        recommendations = recommendMovie(userNum)
        moviesdata = getMovies()
        return render_template('recommendations.html',methods=method, userNum=userNum,firstname=firstname,lastname=lastname,
                               email=email,mydict=mydict,recommendations=recommendations, moviesdata=moviesdata)

@app.route('/sendingmails', methods=['POST','GET'])
def emailSend():
    if request.method == 'POST':
        email= request.form['email']
        userNum= int(request.form['userid'])
        recommendations = recommendMovie(userNum)
        moviesdata = getMovies()
        myList = []
        for r in recommendations:
            for ml in moviesdata:
                for key,values in ml.items():
                    if r == key:
                        myList.append(values)
        
        
        method = "POST"
        
        insertData(userNum,myList)
        
        requests.post("https://api.mailgun.net/v3/sandboxcf02a8cfc5854b26ab2faa632f779fa6.mailgun.org/messages",
              auth=("api", "API_KEY"), # Replace this with the API key for the web service
              data={
                      "from": "info7374@sandboxcf02a8cfc5854b26ab2faa632f779fa6.mailgun.org",
                        "to": [email],
                        "subject": "Here's your recent recommendation",
                        "html": render_template('template.html',myList=myList),
                        "t:text" : "yes"
              })
        return render_template('sendemail.html')
      
@app.route('/analytics')
def analytics():
    return render_template('analytics.html')

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Aug/2019 23:08:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2019 23:09:07] "GET /marketing HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2019 23:09:18] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2019 23:09:33] "POST /recommendations HTTP/1.1" 200 -

# %% [markdown]
# ### Code for inserting recommended movies

# %%
cust,movies = getData()
moviesdata = getMovies()

myList = []
for index,row in cust.iterrows():
    user = row['user_id']
    print(myList)
    recommendations = recommendMovie(int(user))
    for r in recommendations:
        for ml in moviesdata:
            for key,values in ml.items():
                if r == key:
                    myList.append(values)
    print(myList)                    
    insertData(int(user),myList)
    myList=[]
# Out:
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Looper']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Spawn']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'That Awkward Moment']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'Looper']
# []
# ['A Lego Brickumentary', 'Looper', 'Born of War', 'Spawn', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Looper', "April Fool's Day", 'Tusk', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'Beverly Hills Chihuahua', "April Fool's Day"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', "April Fool's Day", 'The Theory of Everything']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Zombieland', 'Rudderless']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'Very Bad Things', 'The Yellow Handkerchief']
# []
# 
"Animal Kingdom: Let's go Ape"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ["Dead Man's Shoes", 'Beverly Hills Chihuahua', 'Sublime', 'Money Monster', 'A Lego Brickumentary']
# []
# ['A Lego Brickumentary', 'Looper', 'Born of War', 'That Awkward Moment', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Rudderless', 'The Yellow Handkerchief', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Tusk']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Very Bad Things', 'Beverly Hills Chihuahua', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Looper', 'That Awkward Moment', 'Tusk']
# []
# ['A Lego Brickumentary', 'Looper', 'That Awkward Moment', "Animal Kingdom: Let's go Ape", 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'The Theory of Everything']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Tusk', 'Very Bad Things', 'The Yellow Handkerchief']
# []
# ["Dead Man's Shoes", 'Born of War', 'Beverly Hills Chihuahua', 'The Fog', 'Cinco de Mayo, La Batalla']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', "Dead Man's Shoes", 'Beverly Hills Chihuahua', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Tusk', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Looper', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Looper', 'Tusk', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', 'Born of War', "Dead Man's Shoes", 'Beverly Hills Chihuahua', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Tusk']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Looper', 'Spawn', 'Born of War']
# []
# ['Beverly Hills Chihuahua', 'Sublime', 'A Lego Brickumentary', "Dead Man's Shoes", 'Down in the Valley']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'The Theory of Everything', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Looper', 'Herbie Fully Loaded', 'That Awkward Moment', "Animal Kingdom: Let's go Ape"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Looper', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'That Awkward Moment', 'Sublime']
# []
# ['A Lego Brickumentary', 'Looper', 'Born of War', 'That Awkward Moment', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', "Dead Man's Shoes", 'Beverly Hills Chihuahua', "April Fool's Day"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Rudderless']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Born of War', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Beverly Hills Chihuahua']
# []
# ['Beverly Hills Chihuahua', 'A Lego Brickumentary', 'Sublime', "Dead Man's Shoes", 'Money Monster']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Very Bad Things', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', 'Legend of Kung Fu Rabbit']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Rudderless', 'Zombieland']
# []
# ['A Lego Brickumentary', "Dead Man's Shoes", 'Born of War', 'The Theory of Everything', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Legend of Kung Fu Rabbit']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'That Awkward Moment', 'Tusk', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Looper', 'Tusk', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Beverly Hills Chihuahua', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'The Yellow Handkerchief', 'Zombieland', 'Very Bad Things']
# []
# ['A Lego Brickumentary', "Dead Man's Shoes", 'Money Monster', 'That Awkward Moment', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'The Theory of Everything']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Legend of Kung Fu Rabbit', 'Sublime']
# []
# ["Dead Man's Shoes", 'Born of War', 'Sublime', 'Beverly Hills Chihuahua', 'Cinco de Mayo, La Batalla']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Looper', "April Fool's Day", 'Rudderless', 'Tusk']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'That Awkward Moment', 'Sublime', 'Down in the Valley']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Sublime', 'Beverly Hills Chihuahua', 'Born of War']
# []
# ["Dead Man's Shoes", 'Beverly Hills Chihuahua', 'Sublime', 'A Lego Brickumentary', 'Born of War']
# []
# ['A Lego Brickumentary', 'Looper', 'That Awkward Moment', "Animal Kingdom: Let's go Ape", 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Money Monster', 'That Awkward Moment', 'Legend of Kung Fu Rabbit']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Born of War', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Beverly Hills Chihuahua', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Spawn']
# []
# ['A Lego Brickumentary', 'Looper', 'Born of War', 'That Awkward Moment', 'Spawn']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Very Bad Things', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'Looper']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Very Bad Things', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Looper', 'Tusk', "April Fool's Day", 'Spawn']
# []
# ['A Lego Brickumentary', 'Looper', "April Fool's Day", 'Tusk', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Rudderless', 'The Yellow Handkerchief', 'Tusk']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Money Monster']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Very Bad Things', 'The Yellow Handkerchief', 'Tusk']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', "April Fool's Day"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Zombieland', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Without Men']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'Beverly Hills Chihuahua', 'Cinco de Mayo, La Batalla']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'That Awkward Moment', 'Spawn', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['Money Monster', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'A Lego Brickumentary', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Looper', 'Born of War', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'The Yellow Handkerchief', 'Zombieland', 'Rudderless']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Zombieland', 'Rudderless']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Rudderless', 'Tusk']
# []
# ["Dead Man's Shoes", 'A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Sublime', "April Fool's Day"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Born of War', 'Very Bad Things']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Very Bad Things', 'Zombieland', 'Born of War']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Spawn']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', 'Born of War', 'Zombieland']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Very Bad Things', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Very Bad Things', 'Zombieland']
# []
# ['Born of War', 'A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Cinco de Mayo, La Batalla', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', 'Born of War', 'Sublime']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', "April Fool's Day", "Dead Man's Shoes"]
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['Beverly Hills Chihuahua', 'A Lego Brickumentary', 'Sublime', "Dead Man's Shoes", 'Money Monster']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Rudderless', 'Zombieland', 'The Yellow Handkerchief']
# []
# ["April Fool's Day", "Dead Man's Shoes", 'Beverly Hills Chihuahua', 'A Lego Brickumentary', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Very Bad Things', 'Zombieland']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Very Bad Things', 'Zombieland', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', 'Looper']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Looper', 'Tusk', 'That Awkward Moment', "April Fool's Day"]
# []
# ['A Lego Brickumentary', "Dead Man's Shoes", "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes", 'Born of War']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'The Theory of Everything']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Rudderless', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Beverly Hills Chihuahua', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Legend of Kung Fu Rabbit', 'Spawn']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Very Bad Things', 'Tusk']
# []
# ['Born of War', 'A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'The Theory of Everything', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Born of War', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Beverly Hills Chihuahua', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'Without Men']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Beverly Hills Chihuahua', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'The Theory of Everything', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Born of War', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", "Dead Man's Shoes", 'Sublime']
# []
# ['Born of War', 'Beverly Hills Chihuahua', 'A Lego Brickumentary', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'That Awkward Moment', 'Sublime']
# []
# ["Dead Man's Shoes", 'Born of War', 'Beverly Hills Chihuahua', 'A Lego Brickumentary', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Beverly Hills Chihuahua', 'Looper']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['Beverly Hills Chihuahua', 'A Lego Brickumentary', 'Sublime', 'Money Monster', 'Down in the Valley']
# []
# ['A Lego Brickumentary', 'That Awkward Moment', 'Beverly Hills Chihuahua', 'Looper', "Animal Kingdom: Let's go Ape"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Zombieland', 'Rudderless']
# []
# ["Dead Man's Shoes", 'Born of War', 'Sublime', 'Cinco de Mayo, La Batalla', 'A Lego Brickumentary']
# []
# ['A Lego Brickumentary', 'Looper', "April Fool's Day", 'That Awkward Moment', 'Born of War']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Sublime', 'Legend of Kung Fu Rabbit', 'Money Monster']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Spawn', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', "Dead Man's Shoes", 'Beverly Hills Chihuahua', 'Cinco de Mayo, La Batalla']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Looper', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'The Theory of Everything', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'That Awkward Moment', "Animal Kingdom: Let's go Ape", 'Looper', 'Tusk']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Looper', 'Beverly Hills Chihuahua', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Looper', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'That Awkward Moment', 'Born of War', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'The Theory of Everything']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'Down in the Valley']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Tusk', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Rudderless', 'The Yellow Handkerchief', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', "Dead Man's Shoes", "April Fool's Day", 'Spawn']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', 'Sublime', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Down in the Valley', 'That Awkward Moment', 'Born of War']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'Beverly Hills Chihuahua', 'Cinco de Mayo, La Batalla']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'Beverly Hills Chihuahua', 'The Theory of Everything']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'Beverly Hills Chihuahua', "Animal Kingdom: Let's go Ape"]
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Looper', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Very Bad Things', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Born of War', 'Spawn', "April Fool's Day", "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'Looper']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'That Awkward Moment', 'Sublime', 'Down in the Valley']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'Looper']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Rudderless', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'The Theory of Everything']
# []
# ['A Lego Brickumentary', 'Money Monster', 'Beverly Hills Chihuahua', 'Legend of Kung Fu Rabbit', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Zombieland', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'Sublime', 'Down in the Valley']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'Beverly Hills Chihuahua', 'That Awkward Moment']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Tusk', 'The Yellow Handkerchief', 'Zombieland']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'The Yellow Handkerchief', 'Rudderless', 'Zombieland']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'The Theory of Everything']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Beverly Hills Chihuahua', 'Looper', 'Born of War']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'The Theory of Everything']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Tusk', 'That Awkward Moment', 'Looper']
# []
# ['Born of War', 'A Lego Brickumentary', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', 'Bad Moms']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Rudderless']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', "Dead Man's Shoes", 'Beverly Hills Chihuahua', 'Sublime']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Looper', 'Born of War', "Animal Kingdom: Let's go Ape", 'Spawn']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "April Fool's Day", 'Looper']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Born of War', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Sublime', 'Looper']
# []
# ['A Lego Brickumentary', 'Born of War', 'Sublime', "Dead Man's Shoes", 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Spawn', 'Born of War', 'Legend of Kung Fu Rabbit', 'Looper']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Zombieland', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', 'Looper', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Rudderless', 'The Yellow Handkerchief']
# []
# ["Dead Man's Shoes", 'Born of War', 'Beverly Hills Chihuahua', 'Money Monster', 'A Lego Brickumentary']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', 'Beverly Hills Chihuahua', 'Sublime']
# []
# ["April Fool's Day", 'A Lego Brickumentary', 'Zombieland', 'The Yellow Handkerchief', 'Very Bad Things']
# []
# ['A Lego Brickumentary', 'Born of War', "April Fool's Day", 'Looper', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Zombieland', 'Rudderless', 'The Yellow Handkerchief']
# []
# ['A Lego Brickumentary', 'Looper', "April Fool's Day", 'Rudderless', 'Tusk']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', 'Born of War', 'Beverly Hills Chihuahua', "Dead Man's Shoes", 'Sublime']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Zombieland', 'Beverly Hills Chihuahua']
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Money Monster', 'Legend of Kung Fu Rabbit', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Beverly Hills Chihuahua', 'Born of War', 'That Awkward Moment', "Dead Man's Shoes"]
# []
# ['A Lego Brickumentary', 'Born of War', 'Looper', "Dead Man's Shoes", 'Cinco de Mayo, La Batalla']
# []
# ['A Lego Brickumentary', 'Looper', 'Born of War', "Animal Kingdom: Let's go Ape", 'The Butterfly Effect']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Born of War', 'Beverly Hills Chihuahua', 'Looper']
# []
# ['A Lego Brickumentary', "April Fool's Day", 'Looper', 'Rudderless', 'Tusk']
# []
# ['A Lego Brickumentary', 'Looper', "April Fool's Day", 'Tusk', 'Born of War']
